# %%
import boto3
import pandas as pd
import io

# %%
REGION = 'us-east-1'
ACCESS_KEY_ID = 'AKIAYQSONWM6J4IWBNOZ'
SECRET_ACCESS_KEY = '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'

# %%
BUCKET_NAME = 'teamairbnb'
KEY = 'NYC_Listing_Q2_2022.csv.gz'

# %%
s3c = boto3.client(
's3',
region_name = REGION,
    aws_access_key_id = ACCESS_KEY_ID,
    aws_secret_access_key = SECRET_ACCESS_KEY)

# %%
obj = s3c.get_object(Bucket=BUCKET_NAME,Key=KEY)
df = pd.read_csv(io.BytesIO(obj['Body'].read()),encoding='utf8',compression="gzip", header=0, sep=",",low_memory=False)

# %%
df.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  2595  https://www.airbnb.com/rooms/2595  20220603182654   2022-06-04
# 1  5121  https://www.airbnb.com/rooms/5121  20220603182654   2022-06-04
# 2  5136  https://www.airbnb.com/rooms/5136  20220603182654   2022-06-04
# 3  5178  https://www.airbnb.com/rooms/5178  20220603182654   2022-06-04
# 4  5203  https://www.airbnb.com/rooms/5203  20220603182654   2022-06-03
#
#                                        name  \
# 0                     Skylit Midtown Castle
# 1                           BlissArtsSpace!
# 2  Spacious Brooklyn Duplex, Patio + Garden
# 3          Large Furnished Room Near B'way
# 4        Cozy Clean Guest Room - Family Apt
#
#                                          description  \
# 0  Beautiful, spacious skylit studio in the heart...
# 1  One room available for rent in a 2 bedroom apt...
# 2  We welcome you to stay in our lovely 2 br dupl...
# ...
